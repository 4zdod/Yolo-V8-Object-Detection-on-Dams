# %%
# !nvidia-smi
# Out:
# Sat Feb 17 05:00:57 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("").project("")
dataset = project.version(2).download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/dams-2/data.yaml epochs=211 imgsz=640

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train3/weights/best.pt conf=0.25 source=/content/dams-2/test/images/Kovvadda-kalva_png_jpg.rf.7e539f9ef6f3060d02bd88b1102c6614.jpg

# %%
display(Image(filename='/content/dams-2/test/images/Kovvadda-kalva_png_jpg.rf.7e539f9ef6f3060d02bd88b1102c6614.jpg', width=600))
print("\n")

# %%
display(Image(filename='/content/runs/detect/predict/Kovvadda-kalva_png_jpg.rf.7e539f9ef6f3060d02bd88b1102c6614.jpg', width=600))
print("\n")

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train3/weights/best.pt conf=0.25 source=/content/dams-2/test/images/MAHESWAR-HYDRO-ELECTRIC-PROJECT_png_jpg.rf.fdc2f191681a40015e14de1c336ea97e.jpg

# %%
display(Image(filename='/content/dams-2/test/images/MAHESWAR-HYDRO-ELECTRIC-PROJECT_png_jpg.rf.fdc2f191681a40015e14de1c336ea97e.jpg', width=600))
print("\n")

# %%
display(Image(filename='/content/runs/detect/predict2/MAHESWAR-HYDRO-ELECTRIC-PROJECT_png_jpg.rf.fdc2f191681a40015e14de1c336ea97e.jpg', width=1000))
print("\n")
